# %%
import pandas as pd

flat = pd.read_csv('flat.csv', encoding='cp1251', sep=',')
problem_ind = flat[flat.spalen.isnull()].index
flat.loc[problem_ind, :] = flat.id_sec[problem_ind].map(lambda x: x.split(',')).tolist()
flat.to_csv('flat_fix.csv', index=False)
